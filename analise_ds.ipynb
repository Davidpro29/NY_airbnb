# %% [markdown]
# Analisando

# %%
import pandas as pd
import numpy as np
import io
from google.colab import files

# %%
file_uploaded = files.upload()
# Out:
#      <input type="file" id="files-5c08068a-c750-47d1-8999-f8183bc49728" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-5c08068a-c750-47d1-8999-f8183bc49728">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %%
df = pd.read_csv( io.BytesIO( file_uploaded['AB_NYC_2019.csv'] ) )

# %%
display(df.head())

# comandos para inspecinar a tabela
# 1 Descobrir o tipo da variável 
type(df)

# Numero de linhas e colunas da tabela
df.shape

# 3. Mostrar as primeiras linhas da tabela
df.head()

# 4. Descobriri os tipos de dados das colunas
df.dtypes

# 5. Numero de dados faltantes da planilha
df.isna().sum()

# 6. Informações gerais sobre a planilha
df.info()

# 7. selecionar colunas 
colunas = ['host_name', 'price']

# df.loc[linhas, colunas]

#df.loc[:, colunas]

consulta1 = df.loc[:, ['host_name', 'price']]

consulta1.head()

# 8.
# Out:
#      id                                              name  host_id  \
# 0  2539                Clean & quiet apt home by the park     2787
# 1  2595                             Skylit Midtown Castle     2845
# 2  3647               THE VILLAGE OF HARLEM....NEW YORK !     4632
# 3  3831                   Cozy Entire Floor of Brownstone     4869
# 4  5022  Entire Apt: Spacious Studio/Loft by central park     7192
#
#      host_name neighbourhood_group neighbourhood  latitude  longitude  \
# 0         John            Brooklyn    Kensington  40.64749  -73.97237
# 1     Jennifer           Manhattan       Midtown  40.75362  -73.98377
# 2    Elisabeth           Manhattan        Harlem  40.80902  -73.94190
# 3  LisaRoxanne            Brooklyn  Clinton Hill  40.68514  -73.95976
# 4        Laura           Manhattan   East Harlem  40.79851  -73.94399
#
#          room_type  price  minimum_nights  number_of_reviews last_review  \
# ...

# %% [markdown]
# **Consultas em colunas**

# %%
colunas = ['host_name', 'price']

# df.loc[linhas, colunas]

#df.loc[:, colunas]

consulta1 = df.loc[:, ['host_name', 'price']]

consulta1.head()
# Out:
#      host_name  price
# 0         John    149
# 1     Jennifer    225
# 2    Elisabeth    150
# 3  LisaRoxanne     89
# 4        Laura     80

# %%
consulta1 = df.dropna()

# %%
consulta1.shape
# Out:
# (38821, 16)

# %% [markdown]
# Respondendo as perguntas do CEO
#
# 1 - média dos aluguéis da cidade = $ 142,33

# %%
preco = ['price']

media = consulta1.loc[:, preco]
np.mean(media)
# Out:
# price    142.332526
# dtype: float64

# %% [markdown]
# 2 - nome das regiões de NY = 'Bronx', 'Brooklyn', 'Manhattan', 'Queens', 'Staten Island

# %%
regiao = ['neighbourhood_group']

bairros = consulta1.loc[:, regiao]

np.unique(bairros)
# Out:
# array(['Bronx', 'Brooklyn', 'Manhattan', 'Queens', 'Staten Island'],
#       dtype=object)

# %% [markdown]
# 3 - Valor de aluguel mais caro da cidade = $10000

# %%
aluguel = ['price']

preco = consulta1.loc[:, aluguel]

np.max(preco)
# Out:
# price    10000
# dtype: int64
